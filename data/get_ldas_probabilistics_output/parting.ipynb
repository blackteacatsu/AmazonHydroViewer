# %%
import xarray as xr
import os

# %%
os.getcwd()
# Out:
# '/Users/kris/GitHub/servir_dashboard_shiny/data/get_ldas_probabilistics_output'

# %%
list_of_variables = {'Rainf_tavg' : 'Average precipitation', 
                    'Qair_f_tavg' : 'Specific humidity',
                    'Qs_tavg':'Surface runoff',
                    'Evap_tavg':'Evapotranspiration',
                    'SoilMoist_inst': 'Soil moisture',
                    'SoilTemp_inst': 'Soil temperature',
                    'Streamflow_tavg': 'Stream flow'}

# %%
ds = xr.open_dataset('prob_2024_12_31_tercile_probability_max_SoilMoist_inst.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 6, lat: 540, lon: 660, category: 3,
#                      SoilMoist_profiles: 4)
# Coordinates:
#   * time            (time) datetime64[ns] 2024-12-31 2025-01-31 ... 2025-05-31
#   * lat             (lat) float64 -20.98 -20.93 -20.88 ... 5.875 5.925 5.975
#   * lon             (lon) float64 -81.97 -81.92 -81.88 ... -49.13 -49.08 -49.03
#   * category        (category) int64 0 1 2
# Dimensions without coordinates: SoilMoist_profiles
# Data variables:
#     SoilMoist_inst  (category, time, SoilMoist_profiles, lat, lon) float64 ...

# %%
for profile_numbers in ds['SoilMoist_profiles'].values:
    print(profile_numbers)
    ds_parted = ds.isel(SoilMoist_profiles = profile_numbers)
    ds_parted.to_netcdf(f'prob_2024_12_31_tercile_probability_max_SoilMoist_inst_lvl_{profile_numbers}.nc')
# Out:
# 0
# 1
# 2
# 3

# %%
xr.open_dataset('prob_2024_12_31_tercile_probability_max_SoilMoist_inst_lvl_0.nc')
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 6, lat: 540, lon: 660, category: 3)
# Coordinates:
#   * time            (time) datetime64[ns] 2024-12-31 2025-01-31 ... 2025-05-31
#   * lat             (lat) float64 -20.98 -20.93 -20.88 ... 5.875 5.925 5.975
#   * lon             (lon) float64 -81.97 -81.92 -81.88 ... -49.13 -49.08 -49.03
#   * category        (category) int64 0 1 2
# Data variables:
#     SoilMoist_inst  (category, time, lat, lon) float64 ...

# %%
ds = xr.open_dataset('prob_2024_12_31_tercile_probability_max_SoilTemp_inst.nc')

for profile_numbers in ds['SoilTemp_profiles'].values:
    print(profile_numbers)
    ds_parted = ds.isel(SoilTemp_profiles = profile_numbers)
    ds_parted.to_netcdf(f'prob_2024_12_31_tercile_probability_max_SoilTemp_inst_lvl_{profile_numbers}.nc')
# Out:
# 0
# 1
# 2
# 3

# %%
xr.open_dataset('prob_2024_12_31_tercile_probability_max_SoilTemp_inst_lvl_0.nc')
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 6, lat: 540, lon: 660, category: 3)
# Coordinates:
#   * time           (time) datetime64[ns] 2024-12-31 2025-01-31 ... 2025-05-31
#   * lat            (lat) float64 -20.98 -20.93 -20.88 ... 5.875 5.925 5.975
#   * lon            (lon) float64 -81.97 -81.92 -81.88 ... -49.13 -49.08 -49.03
#   * category       (category) int64 0 1 2
# Data variables:
#     SoilTemp_inst  (category, time, lat, lon) float64 ...
